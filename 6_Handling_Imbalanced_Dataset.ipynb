# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamSingh-dev/Machine-Learning/blob/main/6_Handling_Imbalanced_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imbalanced Dataset:
# A dataset with an unequal class distribution

# %%
# importing the dependencies
import numpy as np
import pandas as pd

# %%
# loading the dataset to pandas Dataframe
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 9960  14837  1.286884 -0.124610  0.148283 -0.259343  0.248357  0.896718
# 9961  14854  1.318742  0.496408  0.114876  0.695262  0.170133 -0.537180
# 9962  14857  1.241757  0.419587  0.806183  0.894811 -0.507886 -1.118126
# 9963  14861  1.304800 -0.052885  0.415235 -0.081725 -0.223525  0.097752
# 9964  14864 -1.747939  3.712444       NaN       NaN       NaN       NaN
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 9960 -0.626627  0.227693  1.618678  ... -0.381864 -0.904515 -0.027985
# 9961  0.025492 -0.272931  1.267298  ... -0.484943 -1.111176  0.028259
# 9962  0.018908 -0.343335  1.210781  ... -0.379396 -0.817785  0.181425
# 9963 -0.561240  0.067228  1.617203  ... -0.379597 -0.929204  0.020955
# 9964       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# distribution of the two calsses
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    9926
# 1.0      38
# Name: count, dtype: int64

# %% [markdown]
# This is highly imbalanced dataset

# %% [markdown]
# 0 --> legit transaction
# 1 --> Fraudulent Transactions

# %%
# separating the legit and froud
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (9926, 31)
# (38, 31)

# %% [markdown]
# Under-sampling

# %% [markdown]
# build a sample dataset containing similar distribution of legit & Fraudulent transaction

# %% [markdown]
# number of fraFraudulent transaction --> 38

# %%
legit_sample = legit.sample(n=38)

# %%
print(legit_sample.shape)
# Out:
# (38, 31)

# %% [markdown]
# concatenate the two DF

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5642  5858 -3.943565 -2.678028  2.792117  3.877222 -2.286225  2.063882
# 7048  9238 -0.969804  0.769959  2.160070 -0.125004 -0.009317  0.164195
# 1746  1352  1.299268  0.353624 -0.152563  0.779754  0.432925 -0.104665
# 7035  9222 -0.498587  0.273468  1.755623 -0.061612  0.193442 -0.029899
# 6463  7705 -0.804271  0.180587  2.728086 -1.790850 -0.483597  0.057280
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5642  2.191719 -0.841329  2.358712  ... -0.897165  1.085426  1.651936
# 7048  0.323466 -0.076136  2.364164  ... -0.233071 -0.043803 -0.212576
# 1746  0.244949 -0.175607 -0.067950  ... -0.248179 -0.695573 -0.147770
# 7035 -0.030569  0.198240  1.745037  ... -0.107221  0.107992 -0.076251
# 6463  0.250570  0.097549  2.485919  ... -0.046078  0.303240 -0.249429
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#        Time        V1        V2         V3         V4        V5        V6  \
# 9035  12597 -2.589617  7.016714 -13.705407  10.343228 -2.954461 -3.055116
# 9179  13126 -2.880042  5.225442 -11.063330   6.689951 -5.759924 -2.244031
# 9252  13323 -5.454362  8.287421 -12.752811   8.594342 -3.106002 -3.179949
# 9487  14073 -4.153014  8.204797 -15.031714  10.330100 -3.994426 -3.250013
# 9509  14152 -4.710529  8.636214 -15.496222  10.313349 -4.351341 -3.322689
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 9035  -9.301289  3.349573 -5.654212  ...  1.887738  0.333998  0.287659
# 9179 -11.199975  4.014722 -3.429304  ...  2.002883  0.351102  0.795255
# 9252  -9.252794  4.245062 -6.329801  ...  1.846165 -0.267172 -0.310804
# 9487 -10.415698  4.620804 -5.711248  ...  1.976988  0.256510  0.485908
# 9509 -10.788373  5.060381 -5.689311  ...  1.990545  0.223785  0.554408
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset["Class"].value_counts()
# Out:
# Class
# 0.0    38
# 1.0    38
# Name: count, dtype: int64

# %% [markdown]
# Data got Balanced
